# %% [markdown]
# Ejercicio 1
# Somos una empresa que tiene varias tiendas de electrodomesticos. Necesitamos un programa para manejar las tiendas, ver las ventas que han tenido, cuántos empleados hay, etc... Para ello vamos a modelizar la tienda en una clase, que tendrá las siguientes características:
#
# Nombre clase: "Tienda"
# Atributos comunes:
# Tipo: "Electrodomésticos"
# Abierta: True
# Atributos propios de cada tienda:
# Nombre - String
# Dirección - String
# Número de empleados - int
# Ventas ultimos 3 meses - Lista de 3 numeros
# Método para calcular las ventas de todos los meses, que devuelva un numero con todas las ventas.
# Método que calcula la media de ventas de los ultimos meses, por empleado
# Método que devuelve en un string el nombre de la tienda, junto con su dirección.
# Método que obtiene las ventas del último mes.
# Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda. Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas), si es mayor o igual de 1000, las ventas hubiesen sido de (1.5 x venta). El método reescribe el atributo de ventas en los últimos 3 meses, y además devuelve las ventas con el aumento.
# Se pide:
#
# Implementar la clase "Tienda"
# Crear tres tiendas con datos inventados
# Comprueba en al menos una de ellas, todo lo implementado en la clase tienda (sus atributos, media de ventas, ventas/empleado...)
# Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle for
# Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
# Seguro que ya has hecho este apartado... Documenta la clase :)

# %%
class tienda:
    #creo la clase tienda
    #y sus dos primeros atributos
    tipo ="Electrodomesticos" 
    abierta = True
    # creo el metodo constructor de la clase tienda pasandole 4 atributos mas
    def __init__(self,nombre,direccion,numEmpleados,listVentas3M):
        #asigno los parametros del constructor a los atributos del objeto
        self.nombre = nombre     
        self.direccion = direccion     
        self.numEmpleados = numEmpleados     
        self.listVentas3M = listVentas3M     
    # creo el metodo ventas totales less trimestre    
    def ventasTotales(self):  
        numTotal=0
        listVentas = self.listVentas3M
        for i in listVentas:
            numTotal = numTotal + int(i)   
        return float(numTotal)
    #creo el metodo que nos da el valotr medio  de las ventas en el trimesstr
    def mediaVentasEmp(self):     
        numTotal = 0
        numMedia = 0
        for i in self.listVentas3M:
            numTotal = numTotal + int(i)   
        numMedia = numTotal / self.numEmpleados
        return numMedia
    #creo el metodoo que nos devolvera el nombre de la tienda
    def  nombreTienda(self):     
        strNombre = ""
        strNombre = self.nombre + " "+ self.direccion
        return strNombre
    #creo el metodo que nos devolvera las ventas del último mes
    def  ventasUltimoMes(self):     
        ventas = list()     
        ventas = self.listVentas3M     
        return ventas[-1]

#Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda. 
#Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas), 
#si es mayor o igual de 1000, las ventas hubiesen sido de (1.5 x venta).
#El método reescribe el atributo de ventas en los últimos 3 meses, y además devuelve las ventas con el aumento.

    def  ventasProyeccion(self,intInversion): 
        ventas = 0
        constMenosDeMil = 1.2
        constMaSDeMil = 1.5
        listVentasMod = List()
        if intInversion < 1000:       
             for i in self.listVentas3M:
                 numTotal =  + int(i) * constMenosDeMil
                 listVentasMod.append  (numTotal)
             self.listVentas3M = listVentasMod    
        else:     
             for i in self.listVentas3M:
                numTotal =  + int(i) * constMaSDeMil
                listVentasMod.append  (numTotal)
             self.listVentas3M = listVentasMod
            
        return listVentasMod

#Comprueba en al menos una de ellas, todo lo implementado en la clase tienda (sus atributos, media de ventas, ventas/empleado...)
#Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle for
#Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
#Seguro que ya has hecho este apartado... Documenta la clase :)


#  def __init__(self,nombre,direccion,numEmpleados,listVentas3M):
#instancio la clase tienda para obtener un objeto del tipo tienda, esta vez al constructor lee paso todos los parametros
tiendaEroski = tienda ("EuskoEroski","Avenida del Funicular",250,(1000,2000,2500))
print("Nombre: " + tiendaEroski.nombre)
print("-------------------")
print("Dirección: " + tiendaEroski.direccion) 
print("Numero Empleados: " + str(tiendaEroski.numEmpleados)) 
print("Ventas: " + str(tiendaEroski.listVentas3M))
print("tipo: " + tiendaEroski.tipo)
print("Abierta: " + str(tiendaEroski.abierta))
print("Las ventas en este trimestre han sido de: " + str(tiendaEroski.ventasTotales()))
print("Las ventas en el último més: " + str(tiendaEroski.ventasUltimoMes()))
print("")
#instancio la clase tienda para obtener un objeto del tipo tienda, esta vez al constructor lee paso todos los parametros
tiendaCarrefour = tienda ("EuskoCarrefour","Blas de Otero",100,(250,300,500))
print("Nombre: " + tiendaCarrefour.nombre)   
print("-------------------")
print("Dirección: " + tiendaCarrefour.direccion) 
print("Numero Empleados: " + str(tiendaCarrefour.numEmpleados)) 
print("Ventas: " + str(tiendaEroski.listVentas3M))
print("tipo: " + tiendaCarrefour.tipo)
print("Abierta: " + str(tiendaCarrefour.abierta))
print("Las ventas en este trimestre han sido de: " + str(tiendaCarrefour.ventasTotales()))
print("Las ventas en el último més: " + str(tiendaCarrefour.ventasUltimoMes()))
print("")
#instancio la clase tienda para obtener un objeto del tipo tienda, esta vez al constructor lee paso todos los parametros
tiendaBM = tienda ("EuskoBM", "Monte Gabika", 50,(53,52,51))
print("Nombre: " + tiendaBM.nombre)
print("-------------------")
print("Dirección: " + tiendaBM.direccion) 
print("Numero Empleados: " + str(tiendaBM.numEmpleados)) 
print("Ventas: " + str(tiendaBM.listVentas3M))
print("tipo: " + tiendaBM.tipo)
print("Abierta: " + str(tiendaBM.abierta))
print("Las ventas en este trimestre han sido de: " + str(tiendaBM.ventasTotales()))
print("Las ventas en el último més: " + str(tiendaBM.ventasUltimoMes()))
print("")

listTiendas = list()
listTiendas.append(tiendaEroski)
listTiendas.append(tiendaCarrefour)
listTiendas.append(tiendaBM)

for i in listTiendas:
    calle = i.direccion
    if "Avenida" in calle:
        print ("La tienda " + str(i.nombre) + " esta en una Avenida")
# Out:
# Nombre: EuskoEroski
# -------------------
# Dirección: Avenida del Funicular
# Numero Empleados: 250
# Ventas: (1000, 2000, 2500)
# tipo: Electrodomesticos
# Abierta: True
# Las ventas en este trimestre han sido de: 5500.0
# Las ventas en el último més: 2500
#
# Nombre: EuskoCarrefour
# -------------------
# Dirección: Blas de Otero
# Numero Empleados: 100
# Ventas: (1000, 2000, 2500)
# tipo: Electrodomesticos
# Abierta: True
# Las ventas en este trimestre han sido de: 1050.0
# Las ventas en el último més: 500
#
# Nombre: EuskoBM
# -------------------
# Dirección: Monte Gabika
# Numero Empleados: 50
# Ventas: (53, 52, 51)
# tipo: Electrodomesticos
# Abierta: True
# Las ventas en este trimestre han sido de: 156.0
# Las ventas en el último més: 51
#
# La tienda EuskoEroski esta en una Avenida

# %% [markdown]
# Ejercicio 2
# En este ejercicio vamos a implementar una clase Perro en Python. La clase tiene las siguientes características:
#
# Cosas que sabemos seguro que tiene un perro
#
# Tiene 4 patas
# 2 orejas
# 2 ojos
# Una velocidad de 0. Por defecto, el perro está parado
# Cuando se inicialice:
#
# El perro será de una determinada raza
# Por defecto tendrá pelo "Marrón", a no ser que se diga lo contrario.
# Por defecto no tendrá dueño, a no ser que se diga lo contrario.
#
#
#
# Se pide:
# Implementa la clase Perro
# Crea un objeto de tipo Perro, sin dueño
# Comprueba que están bien todos sus atributos
# Prueba que ande, y comprueba su velocidad
# Páralo
# Documenta la clase Perro
#
# Dispondrá también de un método llamado andar, que tiene un argumento de entrada (aumento_velocidad). Este valor se le sumará a la velocidad que ya llevaba el perro.
# Necesita otro método (parar), donde pondremos la velocidad a 0.
# Otro método llamado "ladrar", que tendrá un argumento de entrada, y la salida será el siguiente string: "GUAU!" + el argumento de entrada.

# %%
class perro:
#cre la clase perro y defino sus atributos atrivullendoles valores
    numPatas = 4 
    numOrejas = 2
    numOjos = 2
    velocidad = 0 
    #creo el metodo constructor de la clase pasandole  como argumentos lo que seran nuevos atributos de la clase
    def __init__(self,strRazaPerro="Pastor Aleman" ,strColorPerro = "Marrón",boolDueno = False):
        self.razaPerro = strRazaPerro     
        self.color = strColorPerro     
        self.dueno = boolDueno     
    #Defino el metodo Aumenta velocidad   
    def aumentarVelocidad(self,numVelocidad):
        self.velocidad = self.velocidad + numVelocidad
        return self
    # defino el megtodo parar
    def pararVelocidad(self):
        self.velocidad = 0
        return self
    #Defino el metodo ladrar
    def ladrar(self,strLadrido):
        print("GUAU!!!!!! " + strLadrido)
        return self
#instancio la clase pero sin argumentos
pastorAleman = perro()
#instancio la clase pero pasandole dos de los tres argumentos posibles
caneCorso = perro("Cane Corso",boolDueno = True)
#instancio la clase pero scon todos argumentos
alabai= perro("Alabai","Canela",True)

#Presento la información que tiene cada uno de los objetos definidos
print ("Raza: " + pastorAleman.razaPerro)
print("---------------------------------")
print ("Color: " + pastorAleman.color)
print ("Dueño: " + str(pastorAleman.dueno))
print ("Velocidad: " + str(pastorAleman.velocidad))
print("LO PONEMOS EN MARCHA")
pastorAleman.aumentarVelocidad(60)
print ("Velocidad: " + str(pastorAleman.velocidad))
print("LO PARAMOS")
pastorAleman.pararVelocidad()
print ("Velocidad: " + str(pastorAleman.velocidad))
pastorAleman.ladrar("QUE VIDA MÁS PERRA")

print("")

print ("Raza: " + caneCorso.razaPerro)
print("---------------------------------")
print ("Color: " + caneCorso.color)
print ("Dueño: " + str(caneCorso.dueno))
print("")

print ("Raza: " + alabai.razaPerro)
print("---------------------------------")
print ("Color: " + alabai.color)
print ("Dueño: " + str(alabai.dueno))
print("")
# Out:
# Raza: Pastor Aleman
# ---------------------------------
# Color: Marrón
# Dueño: False
# Velocidad: 0
# LO PONEMOS EN MARCHA
# Velocidad: 60
# LO PARAMOS
# Velocidad: 0
# GUAU!!!!!! QUE VIDA MÁS PERRA
#
# Raza: Cane Corso
# ---------------------------------
# Color: Marrón
# Dueño: True
#
# Raza: Alabai
# ---------------------------------
# Color: Canela
# Dueño: True
